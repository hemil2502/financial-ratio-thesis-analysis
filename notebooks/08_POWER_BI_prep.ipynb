# %%
from pathlib import Path
import pandas as pd
import numpy as np

EXPORT_DIR = Path(
    "/content/drive/MyDrive/IBS_7_Thesis/PowerBI_Exports"
)
EXPORT_DIR.mkdir(parents=True, exist_ok=True)

# Change this to the actual final dataframe name
analysis_df = df_final_analysis.copy()

print("Rows:", len(analysis_df))
print("Columns:", analysis_df.shape[1])
display(analysis_df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_47972/3390964882.py in <cell line: 0>()
#       9
#      10 # Change this to the actual final dataframe name
# ---> 11 analysis_df = df_final_analysis.copy()
#      12
#      13 print("Rows:", len(analysis_df))
#
# NameError: name 'df_final_analysis' is not defined

# %% [markdown]
# ### **STAGE 1B - Rename Columns into Power BI-friendly names**

# %%
df_pbi = df_final.copy()

rename_map = {
    "Name": "company_name",
    "Rechtsform": "legal_form",
    "Land": "country",
    "PLZ": "postal_code",
    "Ort": "city",
    "HR Amtsgericht": "register_court",
    "Register-ID": "register_id",
    "Status": "status",
    "North Data URL": "northdata_url",
    "Branche (WZ)": "wz_full",
    "Finanzkennzahlen Datum": "financial_date",
    "Bilanzsumme EUR": "total_assets",
    "Gewinn EUR": "profit",
    "Umsatz EUR": "revenue",
    "Eigenkapital EUR": "equity",
    "Mitarbeiterzahl": "employees",
    "Kassenbestand EUR": "cash",
    "Forderungen EUR": "receivables",
    "Verbindlichkeiten EUR": "liabilities"
}

df_pbi = df_pbi.rename(columns=rename_map)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_47972/2692609347.py in <cell line: 0>()
# ----> 1 df_pbi = df_final.copy()
#       2
#       3 rename_map = {
#       4     "Name": "company_name",
#       5     "Rechtsform": "legal_form",
#
# NameError: name 'df_final' is not defined
